# %% [markdown]
# # Import the datasets for steps

# %%
library(readr)
library(dplyr)
library(tidyverse)
library(ggplot2)

# Import datasets: 3/4 tables (daily, hourly, Minutes wide and narrow)
dailySteps_merged <- read_csv("/kaggle/input/bellabeat/Fitabase Data 4.12.16-5.12.16/dailySteps_merged.csv")
hourlySteps_merged <- read_csv("/kaggle/input/bellabeat/Fitabase Data 4.12.16-5.12.16/hourlySteps_merged.csv")
minuteStepsNarrow_merged <- read_csv("/kaggle/input/bellabeat/Fitabase Data 4.12.16-5.12.16/minuteStepsNarrow_merged.csv")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.5
# ✔ tibble  3.1.8     ✔ stringr 1.4.1
# ✔ tidyr   1.2.1     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# Rows: 940 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): ActivityDay
# dbl (2): Id, StepTotal
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 22099 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): ActivityHour
# dbl (2): Id, StepTotal
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ...

# %% [markdown]
# ## Group, sort and ﬁlter the data

# %%
hourlySteps_merged <- hourlySteps_merged %>% group_by(Id)
hourlySteps_merged

minuteStepsNarrow_merged <- minuteStepsNarrow_merged %>% group_by(Id)
minuteStepsNarrow_merged

dailySteps_merged <- dailySteps_merged %>% group_by(Id)
dailySteps_merged
# Out:
#       Id         ActivityHour          StepTotal
# 1     1503960366 4/12/2016 12:00:00 AM  373
# 2     1503960366 4/12/2016 1:00:00 AM   160
# 3     1503960366 4/12/2016 2:00:00 AM   151
# 4     1503960366 4/12/2016 3:00:00 AM     0
# 5     1503960366 4/12/2016 4:00:00 AM     0
# 6     1503960366 4/12/2016 5:00:00 AM     0
# 7     1503960366 4/12/2016 6:00:00 AM     0
# 8     1503960366 4/12/2016 7:00:00 AM     0
# 9     1503960366 4/12/2016 8:00:00 AM   250
# 10    1503960366 4/12/2016 9:00:00 AM  1864
# 11    1503960366 4/12/2016 10:00:00 AM  676
# 12    1503960366 4/12/2016 11:00:00 AM  360
# 13    1503960366 4/12/2016 12:00:00 PM  253
# 14    1503960366 4/12/2016 1:00:00 PM   221
# 15    1503960366 4/12/2016 2:00:00 PM  1166
# 16    1503960366 4/12/2016 3:00:00 PM  2063
# 17    1503960366 4/12/2016 4:00:00 PM   344
# 18    1503960366 4/12/2016 5:00:00 PM   489
# 19    1503960366 4/12/2016 6:00:00 PM  1386
# 20    1503960366 4/12/2016 7:00:00 PM   558
# ...

# %% [markdown]
# ## Summarize data

# %%
dailySteps_summarized <- dailySteps_merged %>%
  group_by(dailySteps_merged$Id) %>%
  summarize(mean(dailySteps_merged$StepTotal)) %>%
  arrange(mean(dailySteps_merged$StepTotal))

dailySteps_summarized
# Out:
#    dailySteps_merged$Id mean(dailySteps_merged$StepTotal)
# 1  1503960366           7637.911
# 2  1624580081           7637.911
# 3  1644430081           7637.911
# 4  1844505072           7637.911
# 5  1927972279           7637.911
# 6  2022484408           7637.911
# 7  2026352035           7637.911
# 8  2320127002           7637.911
# 9  2347167796           7637.911
# 10 2873212765           7637.911
# 11 3372868164           7637.911
# 12 3977333714           7637.911
# 13 4020332650           7637.911
# 14 4057192912           7637.911
# 15 4319703577           7637.911
# 16 4388161847           7637.911
# 17 4445114986           7637.911
# 18 4558609924           7637.911
# 19 4702921684           7637.911
# 20 5553957443           7637.911
# 21 5577150313           7637.911
# 22 6117666160           7637.911
# 23 6290855005           7637.911
# 24 6775888955           7637.911
# 25 6962181067           7637.911
# 26 7007744171           7637.911
# ...

# %% [markdown]
# ## Check for null rows

# %%
is.null(dailySteps_merged$Id)
is.null(dailySteps_merged$StepTotal)
is.null(dailySteps_merged$ActivityDay)

is.null(hourlySteps_merged$Id)
is.null(hourlySteps_merged$StepTotal)
is.null(hourlySteps_merged$ActivityHour)

is.null(minuteStepsNarrow_merged$Id)
is.null(minuteStepsNarrow_merged$Steps)
is.null(minuteStepsNarrow_merged$ActivityMinute)
# Out:
# [1] FALSE
# [1] FALSE
# [1] FALSE
# [1] FALSE
# [1] FALSE
# [1] FALSE
# [1] FALSE
# [1] FALSE
# [1] FALSE

# %% [markdown]
# ## Macro-Visualization

# %%
ggplot(dailySteps_merged,
       aes(dailySteps_merged$ActivityDay, dailySteps_merged$StepTotal, color = Id)) + geom_point()
